# %%
import pandas as pd
import numpy as np
import seaborn as sns
data3 = pd.read_csv('df3.csv')
# %matplotlib inline

# %%
data3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
data3.plot.scatter(x='a', y='b', c='r', figsize=(15,3), marker='o', s=50 )

# %%
sns.set_style('white')
data3['a'].plot.hist()

# %%
#sns.set(style='darkgrid')
plt.style.use('ggplot')
data3['a'].plot.hist(bins=25, color='red', alpha=0.3)

# %%
data3[['a', 'b']].plot.box(color='red')

# %%
data3['d'].plot.kde()

# %%
data3['d'].plot.kde(color='red', lw=5, ls=':')

# %%
import matplotlib.pyplot as plt
data3.plot.area(alpha=0.3)
plt.legend(loc=3)

# %%
data3.ix[0:30].plot.area(alpha=0.3)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
data3[0:31].plot.area(alpha=0.5)

# %%
#data3.ix[0:30]

# %%
f = plt.figure()
data3.ix[0:30].plot.area(alpha=0.4, ax=f.gca() )
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
data3.ix[0:30].plot.area(alpha=0.4)
plt.legend(loc='center right', bbox_to_anchor=(1.2, 0.5))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
tt = pd.read_csv('HR_comma_sep.csv')
tt.head(2)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium

# %%
pd.crosstab(tt.salary, tt.left).plot(kind='bar')

# %%
sns.countplot(x='salary', data=tt, hue='left')

# %% [markdown]
# ######
