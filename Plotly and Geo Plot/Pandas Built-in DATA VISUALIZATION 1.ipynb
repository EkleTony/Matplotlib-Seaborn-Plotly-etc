# %%
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
import seaborn as sns
sns.set(style='darkgrid')

# %%
data1 = pd.read_csv('df1.csv', index_col=0)
data1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
data2 = pd.read_csv('df2.csv')
data2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
#histogram

data1['A'].hist(bins=30)

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
hr= pd.read_csv('HR_comma_sep.csv')
hr.head(2)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium

# %%
hr['salary'].hist()

# %%
sns.countplot(x='salary', data=hr)

# %%
#alternative way

# %%
data1['A'].plot(kind='hist', bins=30)

# %%
data1['A'].hist()

# %%
# another one is:

data1['A'].plot.hist()

# %%
data1['A'].plot.hist()

# %%
data2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
data2.plot.area(alpha=0.4)

# %%
data2.plot.area()

# %%
data2.plot.bar(stacked=True)

# %%
data1['A'].plot.hist(bins=50)

# %%
data1.head(3)
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638

# %%
data1.plot.line(figsize=(12,3), lw=1)

# %%
#scatter plot

# %%
data1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
data1.plot.scatter(x='A', y='B', s=data1['C']*50)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#box plot

data1.plot.box()

# %%
#hexagonal beam plot
print(df.head())
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a', y='b', gridsize=25, cmap='Pastel1')
# Out:
#           a         b
# 0 -0.962012  0.015479
# 1 -1.127233  0.124143
# 2  0.427571 -0.406183
# 3 -0.629627  0.825089
# 4  0.055257  1.910767

# %%
# KERNEL DENSITY ESTIMATION PLOT

# %%
data2['a'].plot.density()

# %%
data2['a'].plot.kde()

# %%
data2.plot.density()

# %%
data2.plot.kde()

# %%
data2['a'].plot.pie(radius=1.5, labels=data2.a)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.pie(data2.a, labels=data2.a, radius=1.5)
plt.show()
#data2
