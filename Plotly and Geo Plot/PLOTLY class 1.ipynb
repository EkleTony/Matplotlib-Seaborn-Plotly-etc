# %%
import pandas as pd
import numpy as np
#import chart_studio.plotly as py

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.7.1

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#DATA 

data = pd.DataFrame(np.random.randn(100, 4), columns='A B C D'.split())

# %%
data.head()
# Out:
#           A         B         C         D
# 0 -0.364543 -1.266098 -0.327008 -0.933517
# 1  0.275464 -0.802109 -1.574317 -0.925821
# 2 -1.775308  0.082747  1.715452  0.473197
# 3 -0.678754 -0.008774  0.788333  1.986740
# 4  1.182400 -0.546396  1.863353 -0.604861

# %%
data2 = pd.DataFrame({'Category': ['A', 'B', 'C'], 'Values': [32,43,50]})

# %%
data2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.iplot()
# Out:
# <div>
#
#
#             <div id="29364538-bc50-4e84-8946-f3fa90b82eb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("29364538-bc50-4e84-8946-f3fa90b82eb6")) {
#                     Plotly.newPlot(
#                         '29364538-bc50-4e84-8946-f3fa90b82eb6',
# ...

# %%
#scatter plot

# %%
data.iplot(kind='scatter', x='A', y='B')
# Out:
# <div>
#
#
#             <div id="680d4d5d-33b5-4a9d-bccf-b23dd04ddd82" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("680d4d5d-33b5-4a9d-bccf-b23dd04ddd82")) {
#                     Plotly.newPlot(
#                         '680d4d5d-33b5-4a9d-bccf-b23dd04ddd82',
# ...

# %%
data.iplot(kind='scatter', x='A', y='B', mode='markers', size=8, symbol='star')
# Out:
# <div>
#
#
#             <div id="632f7c55-156d-4071-be95-1802584606fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("632f7c55-156d-4071-be95-1802584606fc")) {
#                     Plotly.newPlot(
#                         '632f7c55-156d-4071-be95-1802584606fc',
# ...

# %%
#Bar plot
data2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
data2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>
#
#
#             <div id="514bef7b-9293-4fd1-9a79-f4e62aba632f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("514bef7b-9293-4fd1-9a79-f4e62aba632f")) {
#                     Plotly.newPlot(
#                         '514bef7b-9293-4fd1-9a79-f4e62aba632f',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
data.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="fa68183f-6d00-4de2-8a28-dace0e827e35" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fa68183f-6d00-4de2-8a28-dace0e827e35")) {
#                     Plotly.newPlot(
#                         'fa68183f-6d00-4de2-8a28-dace0e827e35',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [5.339718185144548, -2.186567151406016, 18.622034241948224, -0.9464028923709988]}],
# ...

# %%
#example using HR_comma_sep

#tt = pd.read_csv('HR_comma_sep.csv')
#tt.head(2)

# %%
#count = tt.groupby('left').count()

# %%
#tt.iplot(kind='bar', x='department', y='left')

# %%
data.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="175f21bf-082a-44c8-8bb6-c65d5279d985" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("175f21bf-082a-44c8-8bb6-c65d5279d985")) {
#                     Plotly.newPlot(
#                         '175f21bf-082a-44c8-8bb6-c65d5279d985',
# ...

# %%
data3 = pd.DataFrame({'x':[1,2,3,4,5], 'y': [10,20,30,20,10], 'z': [500,400,300,200,100]})

# %%
data3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
#three dimensional plot

# %%
data3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="992a185c-6caf-4895-bb5c-5e0ec14543d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("992a185c-6caf-4895-bb5c-5e0ec14543d9")) {
#                     Plotly.newPlot(
#                         '992a185c-6caf-4895-bb5c-5e0ec14543d9',
# ...

# %%
#HISTOGRAM PLOT

# %%
data['A'].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="10150385-18a4-43d4-b6dd-83796ab46518" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("10150385-18a4-43d4-b6dd-83796ab46518")) {
#                     Plotly.newPlot(
#                         '10150385-18a4-43d4-b6dd-83796ab46518',
# ...

# %%
data.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="7a20f9c0-0e78-4429-b12b-8a2bb70e2666" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7a20f9c0-0e78-4429-b12b-8a2bb70e2666")) {
#                     Plotly.newPlot(
#                         '7a20f9c0-0e78-4429-b12b-8a2bb70e2666',
# ...

# %%
#spread

data[['A', 'B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="592b5e2d-c3a6-4e8f-94ef-e174f2f10fc4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("592b5e2d-c3a6-4e8f-94ef-e174f2f10fc4")) {
#                     Plotly.newPlot(
#                         '592b5e2d-c3a6-4e8f-94ef-e174f2f10fc4',
# ...

# %%
#bubld  plot

# %%
data.iplot(kind='bubble', x='A', y='B', size='C', colors='orange')
# Out:
# <div>
#
#
#             <div id="3b2404b9-781f-4ec8-a2fc-e34945a5fd2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3b2404b9-781f-4ec8-a2fc-e34945a5fd2c")) {
#                     Plotly.newPlot(
#                         '3b2404b9-781f-4ec8-a2fc-e34945a5fd2c',
# ...

# %%
#scatter matrix

# %%
data.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="81d1efb8-3d48-4ef1-a2d7-a44f0b8e35be" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81d1efb8-3d48-4ef1-a2d7-a44f0b8e35be")) {
#                     Plotly.newPlot(
#                         '81d1efb8-3d48-4ef1-a2d7-a44f0b8e35be',
# ...
